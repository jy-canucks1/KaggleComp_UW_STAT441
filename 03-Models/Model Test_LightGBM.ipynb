# %%
import lightgbm as lgb
import pandas as pd
import numpy as np
from sklearn.metrics import classification_report
from sklearn.metrics import log_loss
from sklearn.model_selection import train_test_split

from EDA_script_original import *
label_mapping = {-1: 0, 1: 1, 2: 2, 3: 3, 4: 4}
df_y = df_y.replace(label_mapping)

# %%
X_train, X_val, y_train, y_val = train_test_split(df_train, df_y, test_size=0.3, random_state=42)

# Define a range of values for the hyperparameters to search through
params = {
    'objective': 'multiclass',
    'num_class': 5,
    'metric': 'multi_logloss',
    'verbose': 2,
    'num_leaves': 20,
    'learning_rate': 0.05,
    'feature_fraction': 0.9,
    'bagging_fraction': 0.8,
    'bagging_freq': 5,
    'min_data_in_leaf':4,
}
train_data = lgb.Dataset(X_train, label=y_train)
valid_data = lgb.Dataset(X_val, label=y_val, reference=train_data)

# %%
evals_result = {} 
# Training the Model
num_round = 1000
model = lgb.train(params,
                  train_data,
                  num_round,
                  early_stopping_rounds=10,
                  valid_sets=[train_data,valid_data],
                  evals_result=evals_result)


y_pred = model.predict(X_val,
                       num_iteration=model.best_iteration)

accuracy = log_loss(y_val, y_pred)
lgb.plot_metric(evals_result, metric='multi_logloss')
lgb.plot_importance(model, max_num_features=30, importance_type="split", figsize=(7,6), title="LightGBM Feature Importance (Weight)")
plt.show()
# Out:
# c:\Users\User\AppData\Local\Programs\Python\Python39\lib\site-packages\lightgbm\engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# c:\Users\User\AppData\Local\Programs\Python\Python39\lib\site-packages\lightgbm\engine.py:260: UserWarning: 'evals_result' argument is deprecated and will be removed in a future release of LightGBM. Pass 'record_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'evals_result' argument is deprecated and will be removed in a future release of LightGBM. "
# [LightGBM] [Debug] Dataset::GetMultiBinFromSparseFeatures: sparse rate 0.880903
# [LightGBM] [Debug] Dataset::GetMultiBinFromAllFeatures: sparse rate 0.223276
# [LightGBM] [Debug] init for col-wise cost 0.006080 seconds, init for row-wise cost 0.022249 seconds
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.028623 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4232
# [LightGBM] [Info] Number of data points in the train set: 33600, number of used features: 337
# [LightGBM] [Info] Start training from score -4.282397
# [LightGBM] [Info] Start training from score -1.579677
# [LightGBM] [Info] Start training from score -1.216351
# [LightGBM] [Info] Start training from score -1.261657
# [LightGBM] [Info] Start training from score -1.606169
# [LightGBM] [Debug] Re-bagging, using 26951 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 6
# [1]	training's multi_logloss: 1.36945	valid_1's multi_logloss: 1.37731
# Training until validation scores don't improve for 10 rounds
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 6
# [2]	training's multi_logloss: 1.33028	valid_1's multi_logloss: 1.34068
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 6
# [3]	training's multi_logloss: 1.29473	valid_1's multi_logloss: 1.30703
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 6
# [4]	training's multi_logloss: 1.26137	valid_1's multi_logloss: 1.27602
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 6
# [5]	training's multi_logloss: 1.23169	valid_1's multi_logloss: 1.24767
# [LightGBM] [Debug] Re-bagging, using 26805 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 6
# [6]	training's multi_logloss: 1.20522	valid_1's multi_logloss: 1.22257
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 6
# [7]	training's multi_logloss: 1.18042	valid_1's multi_logloss: 1.19934
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 6
# [8]	training's multi_logloss: 1.15776	valid_1's multi_logloss: 1.17807
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [9]	training's multi_logloss: 1.13726	valid_1's multi_logloss: 1.15879
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 5
# [10]	training's multi_logloss: 1.11892	valid_1's multi_logloss: 1.14151
# [LightGBM] [Debug] Re-bagging, using 26901 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 6
# [11]	training's multi_logloss: 1.10147	valid_1's multi_logloss: 1.12557
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [12]	training's multi_logloss: 1.08527	valid_1's multi_logloss: 1.11066
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 6
# [13]	training's multi_logloss: 1.07049	valid_1's multi_logloss: 1.09721
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 6
# [14]	training's multi_logloss: 1.05696	valid_1's multi_logloss: 1.08454
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [15]	training's multi_logloss: 1.04397	valid_1's multi_logloss: 1.0727
# [LightGBM] [Debug] Re-bagging, using 26882 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 6
# [16]	training's multi_logloss: 1.03196	valid_1's multi_logloss: 1.06168
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 6
# [17]	training's multi_logloss: 1.02116	valid_1's multi_logloss: 1.05189
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [18]	training's multi_logloss: 1.01073	valid_1's multi_logloss: 1.04248
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 6
# [19]	training's multi_logloss: 1.00063	valid_1's multi_logloss: 1.03384
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [20]	training's multi_logloss: 0.991849	valid_1's multi_logloss: 1.02581
# [LightGBM] [Debug] Re-bagging, using 26658 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 6
# [21]	training's multi_logloss: 0.98331	valid_1's multi_logloss: 1.01837
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 6
# [22]	training's multi_logloss: 0.975346	valid_1's multi_logloss: 1.01124
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [23]	training's multi_logloss: 0.967704	valid_1's multi_logloss: 1.00441
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 6
# [24]	training's multi_logloss: 0.960456	valid_1's multi_logloss: 0.998205
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [25]	training's multi_logloss: 0.953821	valid_1's multi_logloss: 0.992475
# [LightGBM] [Debug] Re-bagging, using 27053 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [26]	training's multi_logloss: 0.947297	valid_1's multi_logloss: 0.986858
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 6
# [27]	training's multi_logloss: 0.941092	valid_1's multi_logloss: 0.981889
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [28]	training's multi_logloss: 0.93539	valid_1's multi_logloss: 0.976972
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [29]	training's multi_logloss: 0.929935	valid_1's multi_logloss: 0.972465
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 6
# [30]	training's multi_logloss: 0.924765	valid_1's multi_logloss: 0.967972
# [LightGBM] [Debug] Re-bagging, using 26899 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [31]	training's multi_logloss: 0.919704	valid_1's multi_logloss: 0.963834
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 6
# [32]	training's multi_logloss: 0.914727	valid_1's multi_logloss: 0.959776
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [33]	training's multi_logloss: 0.910013	valid_1's multi_logloss: 0.955797
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [34]	training's multi_logloss: 0.905615	valid_1's multi_logloss: 0.952142
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [35]	training's multi_logloss: 0.90121	valid_1's multi_logloss: 0.948526
# [LightGBM] [Debug] Re-bagging, using 26922 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [36]	training's multi_logloss: 0.896896	valid_1's multi_logloss: 0.94497
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [37]	training's multi_logloss: 0.892941	valid_1's multi_logloss: 0.941713
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [38]	training's multi_logloss: 0.889155	valid_1's multi_logloss: 0.938724
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [39]	training's multi_logloss: 0.885384	valid_1's multi_logloss: 0.936015
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 6
# [40]	training's multi_logloss: 0.881823	valid_1's multi_logloss: 0.933426
# [LightGBM] [Debug] Re-bagging, using 27016 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 6
# [41]	training's multi_logloss: 0.878352	valid_1's multi_logloss: 0.930848
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [42]	training's multi_logloss: 0.875001	valid_1's multi_logloss: 0.928562
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 6
# [43]	training's multi_logloss: 0.871834	valid_1's multi_logloss: 0.9263
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 6
# [44]	training's multi_logloss: 0.868624	valid_1's multi_logloss: 0.924089
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 6
# [45]	training's multi_logloss: 0.865577	valid_1's multi_logloss: 0.921953
# [LightGBM] [Debug] Re-bagging, using 26790 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 6
# [46]	training's multi_logloss: 0.862541	valid_1's multi_logloss: 0.920161
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [47]	training's multi_logloss: 0.859553	valid_1's multi_logloss: 0.918153
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [48]	training's multi_logloss: 0.856718	valid_1's multi_logloss: 0.916453
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [49]	training's multi_logloss: 0.854083	valid_1's multi_logloss: 0.91454
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [50]	training's multi_logloss: 0.851431	valid_1's multi_logloss: 0.912785
# [LightGBM] [Debug] Re-bagging, using 26931 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 6
# [51]	training's multi_logloss: 0.848977	valid_1's multi_logloss: 0.911259
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [52]	training's multi_logloss: 0.84647	valid_1's multi_logloss: 0.909614
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [53]	training's multi_logloss: 0.844085	valid_1's multi_logloss: 0.908142
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [54]	training's multi_logloss: 0.841665	valid_1's multi_logloss: 0.906808
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 10
# [55]	training's multi_logloss: 0.839388	valid_1's multi_logloss: 0.905428
# [LightGBM] [Debug] Re-bagging, using 26914 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [56]	training's multi_logloss: 0.83694	valid_1's multi_logloss: 0.903828
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [57]	training's multi_logloss: 0.834711	valid_1's multi_logloss: 0.902354
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [58]	training's multi_logloss: 0.83232	valid_1's multi_logloss: 0.900833
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [59]	training's multi_logloss: 0.830191	valid_1's multi_logloss: 0.899562
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [60]	training's multi_logloss: 0.828115	valid_1's multi_logloss: 0.898296
# [LightGBM] [Debug] Re-bagging, using 26751 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [61]	training's multi_logloss: 0.826032	valid_1's multi_logloss: 0.897154
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [62]	training's multi_logloss: 0.823926	valid_1's multi_logloss: 0.89592
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 6
# [63]	training's multi_logloss: 0.821846	valid_1's multi_logloss: 0.894715
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [64]	training's multi_logloss: 0.819697	valid_1's multi_logloss: 0.893667
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [65]	training's multi_logloss: 0.817757	valid_1's multi_logloss: 0.892636
# [LightGBM] [Debug] Re-bagging, using 26886 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [66]	training's multi_logloss: 0.815849	valid_1's multi_logloss: 0.891673
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [67]	training's multi_logloss: 0.814059	valid_1's multi_logloss: 0.890802
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [68]	training's multi_logloss: 0.812286	valid_1's multi_logloss: 0.889921
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [69]	training's multi_logloss: 0.810603	valid_1's multi_logloss: 0.889194
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 6
# [70]	training's multi_logloss: 0.808857	valid_1's multi_logloss: 0.888508
# [LightGBM] [Debug] Re-bagging, using 26826 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [71]	training's multi_logloss: 0.807019	valid_1's multi_logloss: 0.887676
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [72]	training's multi_logloss: 0.8053	valid_1's multi_logloss: 0.886871
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [73]	training's multi_logloss: 0.803625	valid_1's multi_logloss: 0.886204
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [74]	training's multi_logloss: 0.801975	valid_1's multi_logloss: 0.885548
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [75]	training's multi_logloss: 0.800291	valid_1's multi_logloss: 0.884891
# [LightGBM] [Debug] Re-bagging, using 26969 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 6
# [76]	training's multi_logloss: 0.798631	valid_1's multi_logloss: 0.884326
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [77]	training's multi_logloss: 0.797019	valid_1's multi_logloss: 0.883801
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [78]	training's multi_logloss: 0.795401	valid_1's multi_logloss: 0.883317
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [79]	training's multi_logloss: 0.793805	valid_1's multi_logloss: 0.882737
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [80]	training's multi_logloss: 0.792219	valid_1's multi_logloss: 0.882073
# [LightGBM] [Debug] Re-bagging, using 26894 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 6
# [81]	training's multi_logloss: 0.790633	valid_1's multi_logloss: 0.881357
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [82]	training's multi_logloss: 0.789064	valid_1's multi_logloss: 0.880761
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [83]	training's multi_logloss: 0.787599	valid_1's multi_logloss: 0.880143
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [84]	training's multi_logloss: 0.786065	valid_1's multi_logloss: 0.879594
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [85]	training's multi_logloss: 0.784646	valid_1's multi_logloss: 0.879173
# [LightGBM] [Debug] Re-bagging, using 26964 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [86]	training's multi_logloss: 0.783053	valid_1's multi_logloss: 0.878461
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [87]	training's multi_logloss: 0.781587	valid_1's multi_logloss: 0.877925
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 6
# [88]	training's multi_logloss: 0.780119	valid_1's multi_logloss: 0.877337
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [89]	training's multi_logloss: 0.778696	valid_1's multi_logloss: 0.87682
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [90]	training's multi_logloss: 0.777188	valid_1's multi_logloss: 0.876417
# [LightGBM] [Debug] Re-bagging, using 26969 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [91]	training's multi_logloss: 0.775716	valid_1's multi_logloss: 0.876036
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [92]	training's multi_logloss: 0.77436	valid_1's multi_logloss: 0.875564
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 10
# [93]	training's multi_logloss: 0.772911	valid_1's multi_logloss: 0.875047
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 10
# [94]	training's multi_logloss: 0.771544	valid_1's multi_logloss: 0.874714
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [95]	training's multi_logloss: 0.770185	valid_1's multi_logloss: 0.874305
# [LightGBM] [Debug] Re-bagging, using 26901 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 10
# [96]	training's multi_logloss: 0.768862	valid_1's multi_logloss: 0.873928
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 10
# [97]	training's multi_logloss: 0.767507	valid_1's multi_logloss: 0.873491
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 10
# [98]	training's multi_logloss: 0.76611	valid_1's multi_logloss: 0.873089
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [99]	training's multi_logloss: 0.764868	valid_1's multi_logloss: 0.872698
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [100]	training's multi_logloss: 0.76354	valid_1's multi_logloss: 0.872253
# [LightGBM] [Debug] Re-bagging, using 26882 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [101]	training's multi_logloss: 0.762163	valid_1's multi_logloss: 0.871923
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [102]	training's multi_logloss: 0.760864	valid_1's multi_logloss: 0.871579
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [103]	training's multi_logloss: 0.759566	valid_1's multi_logloss: 0.871293
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 11
# [104]	training's multi_logloss: 0.758393	valid_1's multi_logloss: 0.871025
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 6
# [105]	training's multi_logloss: 0.757148	valid_1's multi_logloss: 0.870646
# [LightGBM] [Debug] Re-bagging, using 26853 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [106]	training's multi_logloss: 0.755894	valid_1's multi_logloss: 0.870359
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [107]	training's multi_logloss: 0.754639	valid_1's multi_logloss: 0.870021
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [108]	training's multi_logloss: 0.753398	valid_1's multi_logloss: 0.86973
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 10
# [109]	training's multi_logloss: 0.752126	valid_1's multi_logloss: 0.869391
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [110]	training's multi_logloss: 0.750932	valid_1's multi_logloss: 0.869173
# [LightGBM] [Debug] Re-bagging, using 26962 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [111]	training's multi_logloss: 0.74977	valid_1's multi_logloss: 0.868983
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [112]	training's multi_logloss: 0.748602	valid_1's multi_logloss: 0.86879
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# ...
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [196]	training's multi_logloss: 0.664081	valid_1's multi_logloss: 0.858674
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [197]	training's multi_logloss: 0.663302	valid_1's multi_logloss: 0.858672
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 10
# [198]	training's multi_logloss: 0.662417	valid_1's multi_logloss: 0.858554
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [199]	training's multi_logloss: 0.661521	valid_1's multi_logloss: 0.858559
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [200]	training's multi_logloss: 0.660672	valid_1's multi_logloss: 0.858575
# [LightGBM] [Debug] Re-bagging, using 26779 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [201]	training's multi_logloss: 0.659831	valid_1's multi_logloss: 0.858514
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [202]	training's multi_logloss: 0.658967	valid_1's multi_logloss: 0.858515
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 6
# [203]	training's multi_logloss: 0.65812	valid_1's multi_logloss: 0.858503
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [204]	training's multi_logloss: 0.657331	valid_1's multi_logloss: 0.858496
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [205]	training's multi_logloss: 0.65653	valid_1's multi_logloss: 0.858499
# [LightGBM] [Debug] Re-bagging, using 26908 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [206]	training's multi_logloss: 0.655728	valid_1's multi_logloss: 0.858525
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 10
# [207]	training's multi_logloss: 0.654893	valid_1's multi_logloss: 0.858426
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [208]	training's multi_logloss: 0.654068	valid_1's multi_logloss: 0.858297
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [209]	training's multi_logloss: 0.653302	valid_1's multi_logloss: 0.858293
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 11
# [210]	training's multi_logloss: 0.652502	valid_1's multi_logloss: 0.858294
# [LightGBM] [Debug] Re-bagging, using 26861 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [211]	training's multi_logloss: 0.651685	valid_1's multi_logloss: 0.858247
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 10
# [212]	training's multi_logloss: 0.650921	valid_1's multi_logloss: 0.858235
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [213]	training's multi_logloss: 0.650171	valid_1's multi_logloss: 0.858172
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 10
# [214]	training's multi_logloss: 0.649344	valid_1's multi_logloss: 0.858287
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 10
# [215]	training's multi_logloss: 0.648545	valid_1's multi_logloss: 0.858268
# [LightGBM] [Debug] Re-bagging, using 26827 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [216]	training's multi_logloss: 0.647642	valid_1's multi_logloss: 0.858255
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 10
# [217]	training's multi_logloss: 0.646869	valid_1's multi_logloss: 0.858214
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [218]	training's multi_logloss: 0.646067	valid_1's multi_logloss: 0.858196
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [219]	training's multi_logloss: 0.645252	valid_1's multi_logloss: 0.85816
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [220]	training's multi_logloss: 0.644538	valid_1's multi_logloss: 0.858255
# [LightGBM] [Debug] Re-bagging, using 27020 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [221]	training's multi_logloss: 0.643706	valid_1's multi_logloss: 0.858241
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [222]	training's multi_logloss: 0.642907	valid_1's multi_logloss: 0.858158
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [223]	training's multi_logloss: 0.642106	valid_1's multi_logloss: 0.85814
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [224]	training's multi_logloss: 0.641319	valid_1's multi_logloss: 0.858011
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [225]	training's multi_logloss: 0.640602	valid_1's multi_logloss: 0.85809
# [LightGBM] [Debug] Re-bagging, using 26851 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [226]	training's multi_logloss: 0.63985	valid_1's multi_logloss: 0.858045
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [227]	training's multi_logloss: 0.639114	valid_1's multi_logloss: 0.858109
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [228]	training's multi_logloss: 0.638356	valid_1's multi_logloss: 0.858152
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [229]	training's multi_logloss: 0.637569	valid_1's multi_logloss: 0.858182
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [230]	training's multi_logloss: 0.636836	valid_1's multi_logloss: 0.858129
# [LightGBM] [Debug] Re-bagging, using 26735 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [231]	training's multi_logloss: 0.636117	valid_1's multi_logloss: 0.858068
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [232]	training's multi_logloss: 0.635388	valid_1's multi_logloss: 0.858149
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [233]	training's multi_logloss: 0.634532	valid_1's multi_logloss: 0.8581
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 9
# [234]	training's multi_logloss: 0.633806	valid_1's multi_logloss: 0.858143
# Early stopping, best iteration is:
# [224]	training's multi_logloss: 0.641319	valid_1's multi_logloss: 0.858011

# %%
y_pred_1 = model.predict(df_test,
                       num_iteration=model.best_iteration)
class_order = [0, 1, 2, 3, 4]
class_mapping = {class_label: f"Class{class_label}" for class_label in class_order}

submission_df = pd.DataFrame(y_pred_1, columns=class_mapping.values())
submission_df.columns = ['no answer', 'very important', 'quite important', 'not important', 'not at all important']
submission_df.insert(0, 'id', df_test.index)

# Save the submission file
submission_file = ('eda_script_og_amy_submission2.csv')
submission_df.to_csv(submission_file, index=False)
